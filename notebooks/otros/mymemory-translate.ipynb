# %% [markdown]
# # Google Translate
#
# Vamos a usar esta librería: [translate](https://github.com/terryyin/translate-python)

# %%
from translate import Translator

es_en_translator = Translator(from_lang="es", to_lang="en", de="jmperez.85@gmail.com")
en_es_translator = Translator(from_lang="en", to_lang="es", de="jmperez.85@gmail.com")

# %%
translator.translate?
# Out:
# Signature: translator.translate(text)
# Docstring: <no docstring>
# File:      ~/.pyenv/versions/3.6.5/envs/hateval/lib/python3.6/site-packages/translate/translate.py
# Type:      method

# %%
text = es_en_translator.translate('dejame de joder, viejo!')

text
# Out:
# 'stop fucking me, old man!'

# %%
en_es_translator.translate(text)
# Out:
# '¡Deja de follarme, viejo!'

# %% [markdown]
# ## Bulk translate

# %%
import pandas as pd
df_train = pd.read_table("../../data/es/train_es.tsv", index_col="id")
df_dev = pd.read_table("../../data/es/dev_es.tsv", index_col="id")

text_train, y_train = df_train["text"], df_train["HS"]
text_dev, y_dev = df_dev["text"], df_dev["HS"]

# %%
from json import JSONDecodeError
trans_tweets = []

for t in df_train.sample(n=100)["text"]:
    try:
        print(("*"*80 + '\n')*2)
        print("Tweet Original\n")
        print(t)

        print("\n####### Traducción")
        
        en_tweet = es_en_translator.translate(t)
        new_tweet = en_es_translator.translate(en_tweet)
        print("\nInglés")
        
        print(en_tweet)
        print("\nRetraducción de inglés")
        
        print(new_tweet)        
    except JSONDecodeError as e:
        print("Problem with translation")
# Out:
# ********************************************************************************
# ********************************************************************************
#
# Tweet Original
#
# Y despues hablabamos de lo que paso en eeuu...nosotros tambien tenemos nuestro Homeland sudaca.... https://t.co/nWbfQAymDr
#
# ####### Traducción
#
# Inglés
# And then we talked about what happened in the USA ... we also have our Homeland sudaca .... https://t.co/nWbfQAymDr
#
# Retraducción de inglés
# Y luego hablamos sobre lo que sucedió en los EE. UU. ... también tenemos nuestra patria sudaca ... https://t.co/nWbfQAymDr
# ********************************************************************************
# ********************************************************************************
#
# Tweet Original
#
# @SIENCIOU @guachicolon ay la puta madre que hermoso gesto, q amor eres lloré, felicidades Luji, te mereces esto tanto
#
# ####### Traducción
#
# Inglés
# ...
