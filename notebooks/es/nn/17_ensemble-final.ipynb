# %% [markdown]
# # Ensembles
#
# En esta notebook vamos a cargar el modelo que mejor anduvo en la CV

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import pandas as pd
import csv

df_dev = pd.read_table("../../../data/es/dev_es.tsv", index_col="id", quoting=csv.QUOTE_NONE)
df_train = pd.read_table("../../../data/es/train_es.tsv", index_col="id", quoting=csv.QUOTE_NONE)
df_test = pd.read_table("../../../data/es/test_es.tsv", index_col="id", quoting=csv.QUOTE_NONE)



X_train, y_train = df_train["text"], df_train["HS"]
X_dev, y_dev = df_dev["text"], df_dev["HS"]

print("Instancias de entrenamiento: {}".format(len(df_train)))
print("Instancias de desarrollo: {}".format(len(df_dev)))
print("Instancias de test: {}".format(len(df_test)))
# Out:
# Instancias de entrenamiento: 4500
# Instancias de desarrollo: 500
# Instancias de test: 1600

# %% [markdown]
# Hagamos tokenize sobre el texto

# %%
# %%capture
from elmoformanylangs import Embedder

e = Embedder("../../../models/elmo/es/", batch_size=32)

# %%
from keras.optimizers import Adam
from keras.utils import plot_model
from hate.nn import CharModel, ElmoModel, BowModel, MergeModel

def create_model(params, embedder):
    params = params.copy()

    dropout = params.pop('dropout')
    recursive_class = params.pop('recursive_class')
    dense_last_layer = params.pop('dense_last_layer')
    char_model = CharModel(
        vocab_size=params.pop('char__vocab_size'),
        max_charlen=params.pop('char__max_charlen'),
        embedding_dim=params.pop('char__embedding_dim'),
        tokenize_args={
            "stem": params.pop('char__stem'),
            "alpha_only": params.pop('char__alpha_only'),
        },
        filters=params.pop('char__filters'),
        kernel_size=params.pop('char__kernel_size'),
        pooling_size=params.pop('char__pooling_size'),
        dense_units=dense_last_layer,
        recursive_class=recursive_class, dropout=dropout
    )
    elmo_model = ElmoModel(
        max_len=50, embedder=embedder,
        lstm_units=params.pop('elmo__lstm_units'),
        tokenize_args={'deaccent': params.pop('elmo__deaccent')},
        dense_units=dense_last_layer,
        recursive_class=recursive_class, dropout=dropout
    )
    bow_model = BowModel(
        num_words=params.pop('bow__num_words'),
        dense_units=[1024, dense_last_layer], dropout=dropout,
    )
    merge_model = MergeModel([char_model, elmo_model, bow_model])
    optimizer_args = {
        "lr": params.pop('lr'),
        "decay": params.pop('decay')
    }
    merge_model.compile(loss='binary_crossentropy',
              optimizer=Adam(**optimizer_args),
              metrics=['accuracy'])

    assert(len(params) == 0)

    return merge_model
# Out:
# Using TensorFlow backend.

# %% [markdown]
# Carguemos los hiperparámetros óptimos

# %%
import pickle

with open("../../../models/model_selection.pkl", "rb") as f:
    model_selection = pickle.load(f)
    
df = pd.DataFrame(model_selection)
df = df.sort_values("val_acc", ascending=False)
df.shape
# Out:
# (73, 6)

# %%
params = df.iloc[0]["params"]

params["lr"] = 0.00035
params["dropout"] = [0.80, 0.55]
params
# Out:
# {'recursive_class': keras.layers.cudnn_recurrent.CuDNNLSTM,
#  'lr': 0.00035,
#  'elmo__lstm_units': 256,
#  'elmo__deaccent': False,
#  'dropout': [0.8, 0.55],
#  'dense_last_layer': 64,
#  'decay': 0.01,
#  'char__vocab_size': 150,
#  'char__stem': False,
#  'char__pooling_size': 4,
#  'char__max_charlen': 200,
#  'char__kernel_size': 7,
#  'char__filters': 256,
#  'char__embedding_dim': 128,
#  'char__alpha_only': False,
#  'bow__num_words': 3500}

# %%
from keras.utils import plot_model
from IPython.display import Image

model = create_model(params, e)

print(model.summary())
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Char_Input (InputLayer)         (None, 200)          0
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 200, 128)     19200       Char_Input[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 200, 256)     229632      embedding_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 50, 256)      0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# Elmo_Input (InputLayer)         (None, 50, 1024)     0
# __________________________________________________________________________________________________
# BoW_Input (InputLayer)          (None, 3500)         0
# __________________________________________________________________________________________________
# bidirectional_1 (Bidirectional) (None, 256)          395264      max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# bidirectional_2 (Bidirectional) (None, 512)          2625536     Elmo_Input[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1024)         3585024     BoW_Input[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 256)          0           bidirectional_1[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 512)          0           bidirectional_2[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 1024)         0           dense_3[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 64)           16448       dropout_1[0][0]
# __________________________________________________________________________________________________
# dense_elmo (Dense)              (None, 64)           32832       dropout_3[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 64)           65600       dropout_5[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 64)           0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 64)           0           dense_elmo[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 64)           0           dense_4[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 192)          0           dropout_2[0][0]
#                                                                  dropout_4[0][0]
#                                                                  dropout_6[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 1)            193         concatenate_1[0][0]
# ==================================================================================================
# Total params: 6,969,729
# Trainable params: 6,969,729
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping

checkpointer = ModelCheckpoint('/tmp/ensemble_17.h5', save_best_only=True, monitor='val_acc', verbose=1)
early_stopper = EarlyStopping(monitor='val_loss', patience=15)
history = model.fit(X_train, y_train, callbacks=[checkpointer, early_stopper],
          validation_data=(X_dev, y_dev), epochs=300, batch_size=32)
# Out:
# Train on 4500 samples, validate on 500 samples
# Epoch 1/300
# 4500/4500 [==============================] - 7s 1ms/step - loss: 0.6924 - acc: 0.5733 - val_loss: 0.6527 - val_acc: 0.6620
#
# Epoch 00001: val_acc improved from -inf to 0.66200, saving model to /tmp/ensemble_17.h5
# Epoch 2/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.6324 - acc: 0.6516 - val_loss: 0.6164 - val_acc: 0.6780
#
# Epoch 00002: val_acc improved from 0.66200 to 0.67800, saving model to /tmp/ensemble_17.h5
# Epoch 3/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.5816 - acc: 0.7176 - val_loss: 0.5820 - val_acc: 0.7360
#
# Epoch 00003: val_acc improved from 0.67800 to 0.73600, saving model to /tmp/ensemble_17.h5
# Epoch 4/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.5419 - acc: 0.7413 - val_loss: 0.5481 - val_acc: 0.7500
#
# Epoch 00004: val_acc improved from 0.73600 to 0.75000, saving model to /tmp/ensemble_17.h5
# Epoch 5/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.5038 - acc: 0.7711 - val_loss: 0.5235 - val_acc: 0.7640
#
# Epoch 00005: val_acc improved from 0.75000 to 0.76400, saving model to /tmp/ensemble_17.h5
# Epoch 6/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.4848 - acc: 0.7829 - val_loss: 0.5038 - val_acc: 0.7640
#
# Epoch 00006: val_acc did not improve from 0.76400
# Epoch 7/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.4681 - acc: 0.7896 - val_loss: 0.4872 - val_acc: 0.7760
#
# Epoch 00007: val_acc improved from 0.76400 to 0.77600, saving model to /tmp/ensemble_17.h5
# Epoch 8/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.4498 - acc: 0.8002 - val_loss: 0.4784 - val_acc: 0.7860
#
# Epoch 00008: val_acc improved from 0.77600 to 0.78600, saving model to /tmp/ensemble_17.h5
# Epoch 9/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.4342 - acc: 0.8120 - val_loss: 0.4708 - val_acc: 0.7940
#
# Epoch 00009: val_acc improved from 0.78600 to 0.79400, saving model to /tmp/ensemble_17.h5
# Epoch 10/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.4264 - acc: 0.8124 - val_loss: 0.4648 - val_acc: 0.8000
#
# Epoch 00010: val_acc improved from 0.79400 to 0.80000, saving model to /tmp/ensemble_17.h5
# Epoch 11/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.4082 - acc: 0.8267 - val_loss: 0.4566 - val_acc: 0.8020
#
# Epoch 00011: val_acc improved from 0.80000 to 0.80200, saving model to /tmp/ensemble_17.h5
# Epoch 12/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.3952 - acc: 0.8376 - val_loss: 0.4534 - val_acc: 0.8040
#
# Epoch 00012: val_acc improved from 0.80200 to 0.80400, saving model to /tmp/ensemble_17.h5
# Epoch 13/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.3904 - acc: 0.8362 - val_loss: 0.4530 - val_acc: 0.8020
#
# Epoch 00013: val_acc did not improve from 0.80400
# Epoch 14/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.3841 - acc: 0.8400 - val_loss: 0.4457 - val_acc: 0.8140
#
# Epoch 00014: val_acc improved from 0.80400 to 0.81400, saving model to /tmp/ensemble_17.h5
# Epoch 15/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.3813 - acc: 0.8427 - val_loss: 0.4448 - val_acc: 0.8160
#
# Epoch 00015: val_acc improved from 0.81400 to 0.81600, saving model to /tmp/ensemble_17.h5
# Epoch 16/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.3623 - acc: 0.8498 - val_loss: 0.4405 - val_acc: 0.8120
#
# Epoch 00016: val_acc did not improve from 0.81600
# Epoch 17/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.3647 - acc: 0.8516 - val_loss: 0.4369 - val_acc: 0.8120
#
# Epoch 00017: val_acc did not improve from 0.81600
# Epoch 18/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.3600 - acc: 0.8491 - val_loss: 0.4386 - val_acc: 0.8120
#
# Epoch 00018: val_acc did not improve from 0.81600
# Epoch 19/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.3512 - acc: 0.8578 - val_loss: 0.4365 - val_acc: 0.8140
#
# Epoch 00019: val_acc did not improve from 0.81600
# Epoch 20/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.3495 - acc: 0.8569 - val_loss: 0.4330 - val_acc: 0.8200
#
# Epoch 00020: val_acc improved from 0.81600 to 0.82000, saving model to /tmp/ensemble_17.h5
# Epoch 21/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.3495 - acc: 0.8551 - val_loss: 0.4313 - val_acc: 0.8180
#
# Epoch 00021: val_acc did not improve from 0.82000
# Epoch 22/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.3381 - acc: 0.8620 - val_loss: 0.4286 - val_acc: 0.8200
#
# Epoch 00022: val_acc did not improve from 0.82000
# Epoch 23/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.3347 - acc: 0.8660 - val_loss: 0.4265 - val_acc: 0.8180
#
# Epoch 00023: val_acc did not improve from 0.82000
# Epoch 24/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.3334 - acc: 0.8611 - val_loss: 0.4283 - val_acc: 0.8180
#
# Epoch 00024: val_acc did not improve from 0.82000
# Epoch 25/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.3299 - acc: 0.8707 - val_loss: 0.4257 - val_acc: 0.8240
#
# Epoch 00025: val_acc improved from 0.82000 to 0.82400, saving model to /tmp/ensemble_17.h5
# Epoch 26/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.3229 - acc: 0.8676 - val_loss: 0.4281 - val_acc: 0.8160
#
# Epoch 00026: val_acc did not improve from 0.82400
# Epoch 27/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.3181 - acc: 0.8702 - val_loss: 0.4223 - val_acc: 0.8260
#
# Epoch 00027: val_acc improved from 0.82400 to 0.82600, saving model to /tmp/ensemble_17.h5
# Epoch 28/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.3213 - acc: 0.8718 - val_loss: 0.4234 - val_acc: 0.8220
#
# Epoch 00028: val_acc did not improve from 0.82600
# Epoch 29/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.3138 - acc: 0.8756 - val_loss: 0.4232 - val_acc: 0.8240
#
# Epoch 00029: val_acc did not improve from 0.82600
# Epoch 30/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.3103 - acc: 0.8780 - val_loss: 0.4213 - val_acc: 0.8260
#
# Epoch 00030: val_acc did not improve from 0.82600
# Epoch 31/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.3164 - acc: 0.8724 - val_loss: 0.4213 - val_acc: 0.8220
#
# Epoch 00031: val_acc did not improve from 0.82600
# Epoch 32/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.3073 - acc: 0.8778 - val_loss: 0.4220 - val_acc: 0.8160
#
# Epoch 00032: val_acc did not improve from 0.82600
# Epoch 33/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.3031 - acc: 0.8802 - val_loss: 0.4219 - val_acc: 0.8200
#
# Epoch 00033: val_acc did not improve from 0.82600
# Epoch 34/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.2937 - acc: 0.8869 - val_loss: 0.4214 - val_acc: 0.8180
#
# Epoch 00034: val_acc did not improve from 0.82600
# Epoch 35/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.2952 - acc: 0.8862 - val_loss: 0.4197 - val_acc: 0.8180
#
# Epoch 00035: val_acc did not improve from 0.82600
# Epoch 36/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.2951 - acc: 0.8864 - val_loss: 0.4186 - val_acc: 0.8200
#
# Epoch 00036: val_acc did not improve from 0.82600
# Epoch 37/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.2880 - acc: 0.8884 - val_loss: 0.4187 - val_acc: 0.8240
#
# Epoch 00037: val_acc did not improve from 0.82600
# Epoch 38/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.2975 - acc: 0.8811 - val_loss: 0.4172 - val_acc: 0.8240
#
# Epoch 00038: val_acc did not improve from 0.82600
# Epoch 39/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.2886 - acc: 0.8918 - val_loss: 0.4182 - val_acc: 0.8220
#
# Epoch 00039: val_acc did not improve from 0.82600
# Epoch 40/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.2801 - acc: 0.8904 - val_loss: 0.4183 - val_acc: 0.8220
#
# Epoch 00040: val_acc did not improve from 0.82600
# Epoch 41/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.2909 - acc: 0.8858 - val_loss: 0.4196 - val_acc: 0.8220
#
# Epoch 00041: val_acc did not improve from 0.82600
# Epoch 42/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.2808 - acc: 0.8924 - val_loss: 0.4180 - val_acc: 0.8220
#
# Epoch 00042: val_acc did not improve from 0.82600
# Epoch 43/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.2837 - acc: 0.8900 - val_loss: 0.4179 - val_acc: 0.8220
#
# Epoch 00043: val_acc did not improve from 0.82600
# Epoch 44/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.2797 - acc: 0.8893 - val_loss: 0.4153 - val_acc: 0.8240
#
# Epoch 00044: val_acc did not improve from 0.82600
# Epoch 45/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.2634 - acc: 0.9013 - val_loss: 0.4161 - val_acc: 0.8200
#
# Epoch 00045: val_acc did not improve from 0.82600
# Epoch 46/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.2734 - acc: 0.8929 - val_loss: 0.4159 - val_acc: 0.8200
#
# Epoch 00046: val_acc did not improve from 0.82600
# Epoch 47/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.2711 - acc: 0.8933 - val_loss: 0.4156 - val_acc: 0.8180
#
# Epoch 00047: val_acc did not improve from 0.82600
# Epoch 48/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.2734 - acc: 0.8951 - val_loss: 0.4149 - val_acc: 0.8200
#
# Epoch 00048: val_acc did not improve from 0.82600
# Epoch 49/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.2717 - acc: 0.8978 - val_loss: 0.4157 - val_acc: 0.8180
#
# Epoch 00049: val_acc did not improve from 0.82600
# Epoch 50/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.2678 - acc: 0.8960 - val_loss: 0.4135 - val_acc: 0.8200
#
# Epoch 00050: val_acc did not improve from 0.82600
# Epoch 51/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.2634 - acc: 0.9009 - val_loss: 0.4119 - val_acc: 0.8240
#
# Epoch 00051: val_acc did not improve from 0.82600
# Epoch 52/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.2697 - acc: 0.8971 - val_loss: 0.4127 - val_acc: 0.8200
#
# Epoch 00052: val_acc did not improve from 0.82600
# Epoch 53/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.2602 - acc: 0.9027 - val_loss: 0.4152 - val_acc: 0.8240
#
# Epoch 00053: val_acc did not improve from 0.82600
# Epoch 54/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.2594 - acc: 0.9027 - val_loss: 0.4141 - val_acc: 0.8220
#
# Epoch 00054: val_acc did not improve from 0.82600
# Epoch 55/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.2582 - acc: 0.9036 - val_loss: 0.4135 - val_acc: 0.8220
#
# Epoch 00055: val_acc did not improve from 0.82600
# Epoch 56/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.2590 - acc: 0.9049 - val_loss: 0.4130 - val_acc: 0.8220
#
# Epoch 00056: val_acc did not improve from 0.82600
# Epoch 57/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.2574 - acc: 0.9042 - val_loss: 0.4126 - val_acc: 0.8180
#
# Epoch 00057: val_acc did not improve from 0.82600
# Epoch 58/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.2519 - acc: 0.9089 - val_loss: 0.4122 - val_acc: 0.8220
#
# Epoch 00058: val_acc did not improve from 0.82600
# Epoch 59/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.2540 - acc: 0.9069 - val_loss: 0.4125 - val_acc: 0.8220
#
# Epoch 00059: val_acc did not improve from 0.82600
# Epoch 60/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.2509 - acc: 0.9098 - val_loss: 0.4121 - val_acc: 0.8200
#
# Epoch 00060: val_acc did not improve from 0.82600
# Epoch 61/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.2448 - acc: 0.9107 - val_loss: 0.4122 - val_acc: 0.8200
#
# Epoch 00061: val_acc did not improve from 0.82600
# Epoch 62/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.2509 - acc: 0.9064 - val_loss: 0.4117 - val_acc: 0.8200
#
# Epoch 00062: val_acc did not improve from 0.82600
# Epoch 63/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.2488 - acc: 0.9056 - val_loss: 0.4132 - val_acc: 0.8240
#
# Epoch 00063: val_acc did not improve from 0.82600
# Epoch 64/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.2441 - acc: 0.9113 - val_loss: 0.4116 - val_acc: 0.8240
#
# Epoch 00064: val_acc did not improve from 0.82600
# Epoch 65/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.2447 - acc: 0.9098 - val_loss: 0.4110 - val_acc: 0.8240
#
# Epoch 00065: val_acc did not improve from 0.82600
# Epoch 66/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.2337 - acc: 0.9147 - val_loss: 0.4106 - val_acc: 0.8260
#
# Epoch 00066: val_acc did not improve from 0.82600
# Epoch 67/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.2418 - acc: 0.9136 - val_loss: 0.4116 - val_acc: 0.8200
#
# Epoch 00067: val_acc did not improve from 0.82600
# Epoch 68/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.2340 - acc: 0.9198 - val_loss: 0.4126 - val_acc: 0.8240
#
# Epoch 00068: val_acc did not improve from 0.82600
# Epoch 69/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.2345 - acc: 0.9142 - val_loss: 0.4113 - val_acc: 0.8260
#
# Epoch 00069: val_acc did not improve from 0.82600
# Epoch 70/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.2380 - acc: 0.9149 - val_loss: 0.4107 - val_acc: 0.8240
#
# Epoch 00070: val_acc did not improve from 0.82600
# Epoch 71/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.2347 - acc: 0.9138 - val_loss: 0.4116 - val_acc: 0.8280
#
# Epoch 00071: val_acc improved from 0.82600 to 0.82800, saving model to /tmp/ensemble_17.h5
# Epoch 72/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.2335 - acc: 0.9178 - val_loss: 0.4104 - val_acc: 0.8300
#
# Epoch 00072: val_acc improved from 0.82800 to 0.83000, saving model to /tmp/ensemble_17.h5
# Epoch 73/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.2336 - acc: 0.9149 - val_loss: 0.4102 - val_acc: 0.8280
#
# Epoch 00073: val_acc did not improve from 0.83000
# Epoch 74/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.2333 - acc: 0.9136 - val_loss: 0.4100 - val_acc: 0.8280
#
# Epoch 00074: val_acc did not improve from 0.83000
# Epoch 75/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.2351 - acc: 0.9118 - val_loss: 0.4108 - val_acc: 0.8280
#
# Epoch 00075: val_acc did not improve from 0.83000
# Epoch 76/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.2297 - acc: 0.9187 - val_loss: 0.4103 - val_acc: 0.8300
#
# Epoch 00076: val_acc did not improve from 0.83000
# Epoch 77/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.2236 - acc: 0.9213 - val_loss: 0.4117 - val_acc: 0.8300
#
# Epoch 00077: val_acc improved from 0.83000 to 0.83000, saving model to /tmp/ensemble_17.h5
# Epoch 78/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.2313 - acc: 0.9158 - val_loss: 0.4102 - val_acc: 0.8300
#
# Epoch 00078: val_acc did not improve from 0.83000
# Epoch 79/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.2250 - acc: 0.9184 - val_loss: 0.4098 - val_acc: 0.8280
#
# Epoch 00079: val_acc did not improve from 0.83000
# Epoch 80/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.2362 - acc: 0.9093 - val_loss: 0.4121 - val_acc: 0.8260
#
# Epoch 00080: val_acc did not improve from 0.83000
# Epoch 81/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.2299 - acc: 0.9176 - val_loss: 0.4115 - val_acc: 0.8280
#
# Epoch 00081: val_acc did not improve from 0.83000
# Epoch 82/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.2278 - acc: 0.9182 - val_loss: 0.4095 - val_acc: 0.8260
#
# Epoch 00082: val_acc did not improve from 0.83000
# Epoch 83/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.2235 - acc: 0.9200 - val_loss: 0.4110 - val_acc: 0.8280
#
# Epoch 00083: val_acc did not improve from 0.83000
# Epoch 84/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.2247 - acc: 0.9184 - val_loss: 0.4110 - val_acc: 0.8300
#
# Epoch 00084: val_acc did not improve from 0.83000
# Epoch 85/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.2268 - acc: 0.9189 - val_loss: 0.4119 - val_acc: 0.8280
#
# Epoch 00085: val_acc did not improve from 0.83000
# Epoch 86/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.2157 - acc: 0.9207 - val_loss: 0.4104 - val_acc: 0.8260
#
# Epoch 00086: val_acc did not improve from 0.83000
# Epoch 87/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.2241 - acc: 0.9176 - val_loss: 0.4111 - val_acc: 0.8300
#
# Epoch 00087: val_acc did not improve from 0.83000
# Epoch 88/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.2247 - acc: 0.9196 - val_loss: 0.4130 - val_acc: 0.8280
#
# Epoch 00088: val_acc did not improve from 0.83000
# Epoch 89/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.2200 - acc: 0.9202 - val_loss: 0.4106 - val_acc: 0.8300
#
# Epoch 00089: val_acc did not improve from 0.83000
# Epoch 90/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.2195 - acc: 0.9202 - val_loss: 0.4128 - val_acc: 0.8280
#
# Epoch 00090: val_acc did not improve from 0.83000
# Epoch 91/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.2183 - acc: 0.9158 - val_loss: 0.4104 - val_acc: 0.8300
#
# Epoch 00091: val_acc did not improve from 0.83000
# Epoch 92/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.2200 - acc: 0.9167 - val_loss: 0.4101 - val_acc: 0.8280
#
# Epoch 00092: val_acc did not improve from 0.83000
# Epoch 93/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.2153 - acc: 0.9191 - val_loss: 0.4114 - val_acc: 0.8280
#
# Epoch 00093: val_acc did not improve from 0.83000
# Epoch 94/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.2184 - acc: 0.9218 - val_loss: 0.4112 - val_acc: 0.8260
#
# Epoch 00094: val_acc did not improve from 0.83000
# Epoch 95/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.2174 - acc: 0.9198 - val_loss: 0.4097 - val_acc: 0.8280
#
# Epoch 00095: val_acc did not improve from 0.83000
# Epoch 96/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.2077 - acc: 0.9233 - val_loss: 0.4124 - val_acc: 0.8280
#
# Epoch 00096: val_acc did not improve from 0.83000
# Epoch 97/300
# 4500/4500 [==============================] - 5s 1ms/step - loss: 0.2116 - acc: 0.9244 - val_loss: 0.4128 - val_acc: 0.8280
#
# Epoch 00097: val_acc did not improve from 0.83000

# %%
from hate.utils import print_evaluation

model.load_weights(checkpointer.filepath)
model.preprocess_fit(X_train)

print_evaluation(model, X_dev, y_dev)
# Out:
# 500/500 [==============================] - 0s 398us/step
# Loss        : 0.4117
# Accuracy    : 0.8300
# Precision   : 0.8128
# Recall      : 0.8018
# F1          : 0.8073

# %% [markdown]
# ## Submission

# %%
df_test["preds"] = (model.predict(df_test["text"]) >= 0.5).astype(int)
df_dev["preds"] = (model.predict(df_dev["text"]) >= 0.5).astype(int)

# %%
# !rm es_a.tsv
# Out:
# rm: cannot remove 'es_a.tsv': No such file or directory

# %%
with open('es_a.tsv', 'w') as f:
    for i, row in df_test.iterrows():
        f.write('{}\t{}\n'.format(i, row["preds"]))

# %%
# !cp es_a.tsv ../../../submissions//17_ensemble.tsv

# %%
import zipfile

with zipfile.ZipFile("es_a.tsv.zip", 'w') as f:
    f.write('es_a.tsv')
